# %% [markdown]
# This notebook reads in files 'prices.csv' and 'stores.json' and reorganizes the data into a cross-tabulation of regional prices alongside each other, broken down by banner, then outputs the data to a spreadsheet.  The notebook also finds any anomolies in the data.

# %%
import pandas as pd
import json
import numpy as np

# %% [markdown]
# Read in json file 'stores.json' and put data into list of dictionaries called store_dict

# %%
with open('stores.json') as f:
    store_dicts = json.load(f)

# %% [markdown]
# Convert list of dictionaries to pandas dataframe named store_df

# %%
store_df = pd.DataFrame(store_dicts)

# %% [markdown]
# read in csv file with pricing data, 'prices.csv', and create pandas dataframe named prices_df

# %%
prices_df = pd.read_csv('prices.csv')

# %% [markdown]
# verify that the store data, store_df, contains all the information needed for our price data by creating a numpy array of all unique store ids in the prices dataframe and a numpy array of all unique store ids in the store dataframe and then comparing the two

# %%
uniq_stores = prices_df['Store ID'].unique()
all_stores = store_df['Store ID'].unique()

# %%
np.setdiff1d(uniq_stores, all_stores)
# Out:
# array([38472, 60957])

# %% [markdown]
# We find that there are two store ids, 38472 and 60957, in our pricing data for which we do not have Banner and Regional data. In the next step we will merge our price and store dataframes by store id as the intersection of keys from both frames, so the prices from the two stores for which we do not have info will simply not be included

# %%
merged = pd.merge(prices_df, store_df, on='Store ID')

# %% [markdown]
# Now we have a dataframe with prices and store info all together.

# %%
merged
# Out:
#        Auditor ID      Date  Price  Store ID        UPC       Banner  \
# 0             234  10/18/17  24.95     66999  268588472      Walmart
# 1             234  10/27/17  49.71     66999  475245085      Walmart
# 2             234  10/20/17  25.75     66999  126967843      Walmart
# 3             234  10/23/17  18.81     66999  708930835      Walmart
# 4             234  10/23/17  33.32     66999  325885139      Walmart
# 5             234  10/16/17  40.43     66999  509419735      Walmart
# 6             234  10/22/17  35.10     66999  736362595      Walmart
# 7             234  10/21/17  33.65     66999  652377244      Walmart
# 8             234  10/16/17  22.30     66999  277394644      Walmart
# 9             234  10/20/17  12.32     66999  996849471      Walmart
# 10            234  10/22/17  18.25     66999  278354885      Walmart
# 11            234  10/23/17  17.35     66999  215480572      Walmart
# 12            234  10/21/17   9.53     66999  526069074      Walmart
# 13            234  10/24/17   9.94     66999  265077864      Walmart
# 14            234  10/18/17  55.21     66999  627831552      Walmart
# 15            234  10/17/17  36.82     66999  992105314      Walmart
# 16            234  10/16/17  61.56     66999   39408244      Walmart
# 17            234  10/20/17   1.34     66999  372268051      Walmart
# 18            234  10/28/17  32.01     66999  375916960      Walmart
# 19            234  10/21/17  44.76     66999  742726716      Walmart
# 20            234  10/18/17   2.65     66999  243131192      Walmart
# 21            234  10/25/17  52.15     66999  388544851      Walmart
# 22            234  10/29/17  48.86     66999  905914857      Walmart
# 23            234  10/28/17   2.22     66999  226080317      Walmart
# 24            234  10/21/17  32.20     66999  502816606      Walmart
# 25            234  10/24/17  61.77     66999  986134213      Walmart
# 26            234  10/18/17  16.64     66999  714264288      Walmart
# 27            234  10/18/17  20.64     66999  585091176      Walmart
# 28            234  10/28/17  38.82     66999  645118810      Walmart
# 29            234  10/17/17  56.14     66999   81313305      Walmart
# ...           ...       ...    ...       ...        ...          ...
# 11481         304  10/23/17  31.69     98736  430094535  Whole Foods
# 11482         304  10/17/17   3.29     98736   17066659  Whole Foods
# 11483         304  10/19/17  13.59     98736  634830299  Whole Foods
# 11484         304  10/19/17  60.29     98736  295208432  Whole Foods
# 11485         304  10/26/17  58.49     98736  319176479  Whole Foods
# 11486         304  10/27/17  17.29     98736  303796970  Whole Foods
# 11487         304  10/25/17   5.19     98736  236468029  Whole Foods
# 11488         304  10/26/17  38.59     98736  212886542  Whole Foods
# 11489         304  10/16/17  24.39     98736  795937333  Whole Foods
# 11490         304  10/25/17  41.79     98736  709096794  Whole Foods
# 11491         304  10/24/17  60.99     98736  162045248  Whole Foods
# 11492         304  10/19/17  42.99     98736  312588009  Whole Foods
# 11493         304  10/23/17  42.29     98736  514912132  Whole Foods
# 11494         304  10/22/17  18.89     98736  978196729  Whole Foods
# 11495         304  10/19/17  17.29     98736  418444428  Whole Foods
# 11496         304  10/23/17   8.49     98736  529559570  Whole Foods
# 11497         304  10/17/17  45.09     98736  804094528  Whole Foods
# 11498         304  10/29/17  36.69     98736  556223651  Whole Foods
# 11499         304  10/29/17  27.19     98736  388197861  Whole Foods
# 11500         304  10/23/17  63.19     98736  165324638  Whole Foods
# 11501         304  10/16/17   7.69     98736  827210689  Whole Foods
# 11502         304  10/29/17  58.39     98736  506732002  Whole Foods
# 11503         304  10/20/17  34.99     98736  545133835  Whole Foods
# 11504         304  10/24/17  50.09     98736  346844734  Whole Foods
# 11505         304  10/19/17  25.89     98736  473279874  Whole Foods
# 11506         304  10/29/17  42.09     98736  700660531  Whole Foods
# 11507         304  10/22/17  20.29     98736  927693101  Whole Foods
# 11508         304  10/24/17   4.09     98736   47174618  Whole Foods
# 11509         304  10/18/17  35.59     98736  182310151  Whole Foods
# 11510         304  10/21/17  37.39     98736  244899396  Whole Foods
#
#                     Region
# 0      Northern California
# 1      Northern California
# 2      Northern California
# 3      Northern California
# 4      Northern California
# 5      Northern California
# 6      Northern California
# 7      Northern California
# 8      Northern California
# 9      Northern California
# 10     Northern California
# 11     Northern California
# 12     Northern California
# 13     Northern California
# 14     Northern California
# 15     Northern California
# 16     Northern California
# 17     Northern California
# 18     Northern California
# 19     Northern California
# 20     Northern California
# 21     Northern California
# 22     Northern California
# 23     Northern California
# 24     Northern California
# 25     Northern California
# 26     Northern California
# 27     Northern California
# 28     Northern California
# 29     Northern California
# ...                    ...
# 11481                Texas
# 11482                Texas
# 11483                Texas
# 11484                Texas
# 11485                Texas
# 11486                Texas
# 11487                Texas
# 11488                Texas
# 11489                Texas
# 11490                Texas
# 11491                Texas
# 11492                Texas
# 11493                Texas
# 11494                Texas
# 11495                Texas
# 11496                Texas
# 11497                Texas
# 11498                Texas
# 11499                Texas
# 11500                Texas
# 11501                Texas
# 11502                Texas
# 11503                Texas
# 11504                Texas
# 11505                Texas
# 11506                Texas
# 11507                Texas
# 11508                Texas
# 11509                Texas
# 11510                Texas
#
# [11511 rows x 7 columns]

# %% [markdown]
# Now we can use a pivot table to transform our sources into a cross-tabulation of regional prices alongside each other broken down by banner

# %%
final_df = pd.pivot_table(merged, values = 'Price', index = ['Banner', 'UPC'], columns = ['Region'])

# %% [markdown]
# Now we can simply write this out to a csv file

# %%
final_df.to_csv('regional_prices.csv')

# %% [markdown]
# If we simply look at the spreadsheet now, one anamolie becomes quite obvious, so I'll print the final dataframe here to show it

# %%
final_df
# Out:
# Region                 Kansas  New York  Northern California  Texas
# Banner      UPC
# Safeway     11873171      NaN       NaN                 6.09   5.19
#             15052612    53.99       NaN                  NaN  54.49
#             16482322    17.89       NaN                  NaN  18.09
#             16729338     7.99       NaN                 9.39   8.09
#             16829288     3.59       NaN                 4.19   3.59
#             16900911    29.19       NaN                34.19  29.49
#             16999755     5.29       NaN                 6.19   5.29
#             17066659     3.09       NaN                 3.59   3.09
#             19696884      NaN       NaN                  NaN   5.89
#             19911643      NaN       NaN                  NaN  30.69
#             19982129    27.39       NaN                  NaN  27.69
#             21872584     7.99       NaN                  NaN    NaN
#             22132676     5.39       NaN                  NaN    NaN
#             22976162    49.59       NaN                58.19  50.09
#             23493525    26.19       NaN                  NaN  26.49
#             24764365      NaN       NaN                  NaN  18.29
#             25023603    14.99       NaN                  NaN  15.19
#             25313327    17.29       NaN                  NaN  17.49
#             26132370      NaN       NaN                23.49  20.19
#             26791818    10.69       NaN                  NaN  10.79
#             26959766    54.39       NaN                63.79  54.99
#             27595398     8.59       NaN                  NaN    NaN
#             27866264    56.39       NaN                66.19  56.99
#             35072231    49.69       NaN                  NaN  50.19
#             38126522    57.29       NaN                  NaN  57.89
#             38399923    38.79       NaN                45.49  39.19
#             39601228    22.69       NaN                  NaN  22.89
#             40555797    27.39       NaN                32.19  27.69
#             41066545    56.09       NaN                  NaN  56.69
#             43366358    46.59       NaN                  NaN  47.09
# ...                       ...       ...                  ...    ...
# Whole Foods 975326196    1.99     30.89                34.79  29.99
#             975793603    1.99     45.99                51.89    NaN
#             976976235    1.99       NaN                72.49  62.49
#             977134983    1.99       NaN                  NaN  34.79
#             978164640    1.99       NaN                  NaN    NaN
#             978196729    1.99     19.49                21.99  18.89
#             979616943    1.99       NaN                  NaN   1.29
#             980113553     NaN       NaN                56.49    NaN
#             980150388    1.99     56.79                63.99  55.09
#             980564443    1.99     38.49                43.39  37.39
#             981197816    1.99     48.89                  NaN    NaN
#             981510405    1.99       NaN                73.69    NaN
#             981620604    1.99     41.39                  NaN  40.19
#             986041768    1.99     26.59                29.99    NaN
#             986134213    1.99     64.19                72.39  62.29
#             987411986    1.99     61.79                  NaN    NaN
#             987897892    1.99      9.89                  NaN   9.59
#             988776021    1.99       NaN                  NaN    NaN
#             988779486    1.99     34.69                39.19    NaN
#             990258086    1.99     43.09                48.59    NaN
#             992105314    1.99     38.29                  NaN    NaN
#             992125856    1.99     49.19                  NaN    NaN
#             993910240    1.99     25.89                29.19    NaN
#             994344572     NaN     11.89                  NaN  11.59
#             995745822     NaN     44.59                  NaN    NaN
#             995798889    1.99     62.39                70.39  60.59
#             996262978    1.99     14.39                16.19  13.89
#             996849471    1.99     12.79                  NaN    NaN
#             998831540    1.99     39.99                  NaN  38.79
#             999185078    1.99     58.09                65.49    NaN
#
# [4931 rows x 4 columns]

# %% [markdown]
# What pops out here is that every price reported from the Whole Foods in Kansas is 1.99.  Let's look a little further for anamolies though. To check for outlier prices, we're going to loop through an all unique upcs, creating a smaller dataframe with all price data for a single product. We will then check this array for any entries whose price is more than three standard deviations from the mean price and append it to an outlier dataframe.

# %%
all_upc = merged['UPC'].unique()  #create array to loop over
outlier_prices = pd.DataFrame(columns = ['Auditor ID', 'Date', 'Price', 'Store ID', 'UPC', 'Banner', 'Region'])
#create empty dataframe for outliers

# %%
for item in all_upc:
    mask = merged['UPC'] ==item
    df = merged[mask]   #create dataframe with all price data for a single upc
    outliers = df[np.abs(df['Price']-df['Price'].mean()) > (3*df['Price'].std())]
    #identify entries with price outside 3 standard deviations of the mean
    outlier_prices = pd.concat([outliers, outlier_prices])  #append outliers to single dataframe

# %%
len(merged)
# Out:
# 11511

# %% [markdown]
# As expected, it looks like we get back all the 1.99 prices from the Whole Foods in Kansas, but let's check if there are any other outliers by grouping the dataframe by price and checking the lenght

# %%
len(outlier_prices.groupby('Price'))
# Out:
# 2

# %%
outlier_prices['Price'].unique() #find out what the other outlier price is
# Out:
# array([ 1.99,  1.49])

# %%
outlier_prices.groupby('Price').get_group(1.49) #let's look at the 1.49 price group
# Out:
#       Auditor ID      Date  Price  Store ID          UPC       Banner  Region
# 7320       713.0  10/29/17   1.49   39287.0  835193761.0  Whole Foods  Kansas

# %% [markdown]
# Interesting that this one came from the same store and same auditor as well.  Let's see if all the outliers came from the same auditor and store location

# %%
len(outlier_prices.groupby(['Banner', 'Region', 'Auditor ID']))
# Out:
# 1

# %% [markdown]
# Yes, when we group by banner, region, and auditor ID, there is only one group meaning all outliers came from the same auditor at the same store location. Let's take a closer look at this particular auditor by making a dataframe with just their data

# %%
auditor713 = merged.groupby('Auditor ID').get_group(713)

# %%
auditor713['Price'].unique()  #did they just price everything 1.99 and one item 1.49?
# Out:
# array([ 51.99,  43.59,  21.39,   1.99,  46.79,  40.99,  26.99,  33.99,
#         54.69,  44.09,  54.19,  55.19,  50.29,  23.29,  17.39,   7.79,
#         39.49,  53.39,  44.19,   3.19,  46.29,  54.29,  34.39,  49.89,
#         53.99,  55.59,  34.99,  56.89,  40.29,  11.29,  21.09,  12.29,
#         39.89,  19.69,  41.99,  12.49,  29.19,  49.99,  13.99,  18.89,
#         10.39,  31.59,   3.69,  24.09,  18.59,  36.39,  45.59,  41.39,
#         12.09,  40.09,  13.09,  36.09,  44.39,  43.19,   1.89,  52.99,
#         17.79,  51.89,  52.39,  47.49,  31.39,   4.89,   2.39,  27.09,
#         35.89,  56.69,  28.69,  51.09,  11.99,  15.69,  38.99,  44.59,
#         11.19,   4.29,  53.69,  10.59,  33.69,  23.69,  47.59,  19.19,
#         35.59,  25.79,   2.99,   7.39,  14.49,  37.89,  35.29,  19.39,
#         56.79,  36.89,  55.69,  43.39,  42.09,  19.09,  37.99,  11.39,
#         38.19,  48.19,  18.49,  40.19,  19.99,   3.49,  32.79,   7.69,
#         50.19,  38.59,  27.49,  17.89,   1.09,  13.59,  35.49,  45.39,
#          9.89,  27.59,  23.79,  22.09,  54.89,  24.39,  15.99,  37.29,
#         17.09,   1.19,  20.69,  30.29,  17.29,  25.19,  15.79,  49.79,
#         53.49,  49.69,  30.19,  56.39,  57.89,  43.89,  46.39,  18.69,
#         16.69,  17.69,  12.79,  14.89,  27.69,  55.39,   8.89,  17.49,
#         18.39,  16.99,  45.89,  17.19,  29.49,  50.69,  28.89,  23.19,
#         14.09,   8.69,  48.49,  27.19,  45.19,   8.59,  49.29,  28.19,
#         54.49,  32.39,  26.09,  48.59,  57.79,  52.19,  11.79,  18.79,
#          3.09,  41.49,  27.99,  40.89,  26.29,   5.19,  28.59,   8.99,
#         12.69,   6.89,  25.09,   5.09,   5.29,  46.69,  22.99,  33.29,
#         38.39,  29.39,  15.89,  14.59,   9.99,   6.09,  36.99,  36.59,
#         44.29,  48.09,  34.49,  29.69,  32.29,  37.09,  16.79,  46.49,
#          8.79,  20.49,  36.79,   1.39,   2.49,   4.69,  16.39,  54.39,
#          6.19,   4.19,  24.99,  41.79,  38.79,  52.79,  28.79,  57.39,
#         54.79,  28.99,  42.69,  33.89,  37.49,  39.79,  22.49,   6.59,
#         22.79,  47.69,  51.39,  51.49,  49.39,  26.59,   6.99,  40.49,
#         55.49,  13.39,   7.99,  47.09,  16.29,  56.49,  25.89,  20.09,
#          9.29,  30.79,  30.59,  21.59,  46.19,  42.29,   2.59,  52.49,
#         32.49,  14.79,  31.19,  27.39,   8.49,  53.19,  50.89,  54.99,
#         49.59,  24.89,  35.39,  47.29,  36.19,  28.29,  20.19,  48.99,
#          7.89,  45.69,  51.69,   7.59,  15.19,  29.09,  50.79,  21.79,
#         39.29,   4.99,   3.39,  10.49,   5.89,  53.09,  12.59,   9.39,
#         26.39,  57.19,   1.59,  26.19,  42.39,   3.59,   2.19,   1.29,
#         50.59,  10.69,  34.29,  56.59,  23.89,  19.59,  39.09,  14.29,
#          1.49])

# %% [markdown]
# No, not everything they priced was 1.99 or 1.49.  Let's check if they went to any stores other than the Whole Foods

# %%
auditor713['Banner'].unique()
# Out:
# array(['Wegmans', 'Whole Foods'], dtype=object)

# %% [markdown]
# Okay, they went to Wegmans and Whole Foods. Let's take a look at the two stores separately

# %%
whole_foods = auditor713.groupby('Banner').get_group('Whole Foods')
wegmans = auditor713.groupby('Banner').get_group('Wegmans')

# %% [markdown]
# Now that we've got a dataframe with the recorded prices for each store, let's see how many unique prices the auditor recorded from each

# %%
whole_foods['Price'].unique()
# Out:
# array([ 1.99,  1.49])

# %%
whole_foods.groupby('Price').get_group(1.49)
# Out:
#       Auditor ID      Date  Price  Store ID        UPC       Banner  Region
# 7320         713  10/29/17   1.49     39287  835193761  Whole Foods  Kansas

# %%
print(len(wegmans['Price'].unique()))
wegmans.groupby('Price').get_group(1.99) #check if anything was priced 1.99 at wegmans too
# Out:
# 296
#       Auditor ID      Date  Price  Store ID        UPC   Banner  Region
# 5628         713  10/21/17   1.99      3948  226080317  Wegmans  Kansas

# %%
len(whole_foods)
# Out:
# 913

# %% [markdown]
# All 913 price entries from the Whole Foods are 1.99 plus the one 1.49 price.  Although our quick sweep to check for outliers did not flag all of these, it is probably best not to trust any of the price entries from Auditor 713 for the Whole Foods in Kansas. This auditor's prices from Wegmans however were not flagged as being more than three standard deviations from the mean and are varied enough that they can likely be trusted. In conclusion, I found two things off with the data collected.
# 1) Store IDs 38472 and 60957 have prices reported in the 'prices.csv' file, but have no corresponding Banner and Region infor in the file 'stores.json'
# 2) All price entries from Auditor 713 for the Whole Foods in Kansas should not be trusted as they are all 1.99 with one 1.49
